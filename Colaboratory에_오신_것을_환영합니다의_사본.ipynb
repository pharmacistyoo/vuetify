# %% [markdown]
# <a href="https://colab.research.google.com/github/pharmacistyoo/vuetify/blob/master/Colaboratory%EC%97%90_%EC%98%A4%EC%8B%A0_%EA%B2%83%EC%9D%84_%ED%99%98%EC%98%81%ED%95%A9%EB%8B%88%EB%8B%A4%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>Colaboratory란?</h1>
#
# 줄여서 'Colab'이라고도 하는 Colaboratory를 사용하면 브라우저에서 Python을 작성하고 실행할 수 있습니다. Colab은 다음과 같은 이점을 자랑합니다.
# - 구성이 필요하지 않음
# - GPU 무료 액세스
# - 간편한 공유
#
# <strong>학생</strong>이든, <strong>데이터 과학자</strong>든, <strong>AI 연구원</strong>이든 Colab으로 업무를 더욱 간편하게 처리할 수 있습니다. <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Colab 소개 영상</a>에서 자세한 내용을 확인하거나 아래에서 시작해 보세요.

# %% [markdown]
# ## <strong>시작하기</strong>
#
# 지금 읽고 계신 문서는 정적 웹페이지가 아니라 코드를 작성하고 실행할 수 있는 대화형 환경인 <strong>Colab 메모장</strong>입니다.
#
# 예를 들어 다음은 값을 계산하여 변수로 저장하고 결과를 출력하는 간단한 Python 스크립트가 포함된 <strong>코드 셀</strong>입니다.

# %%
import pandas as pd
import numpy as np
import xlrd
from collections import OrderedDict

# %% [markdown]
# 위 셀의 코드를 실행하려면 셀을 클릭하여 선택한 후 코드 왼쪽의 실행 버튼을 누르거나 단축키 'Command/Ctrl+Enter'를 사용하세요. 셀을 클릭하면 코드 수정을 바로 시작할 수 있습니다.
#
# 특정 셀에서 정의한 변수를 나중에 다른 셀에서 사용할 수 있습니다.

# %%
main = pd.read_excel('work.xlsx', sheet_name="메인앱", index_col=None)

commo = pd.read_excel('work.xlsx', sheet_name="상품정보")
# commo2 = commo.set_index("제품")

consult= pd.read_excel('work.xlsx', sheet_name="상담내용정리", index_col=None)

commo2.to_dict(orient="index")


commo2 = commo.set_index("제품명")
commo2

commoinfo = commo2.to_dict(orient="index")

# %% [markdown]
# Colab 메모장을 사용하면 <strong>실행 코드</strong>와 <strong>서식 있는 텍스트</strong>를 <strong>이미지</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> 등과 함께 하나의 문서로 통합할 수 있습니다. Colab 메모장을 만들면 Google 드라이브 계정에 저장됩니다. Colab 메모장을 간편하게 공유하여 동료나 친구들이 댓글을 달거나 수정하도록 할 수 있습니다. 자세히 알아보려면 <a href="/notebooks/basic_features_overview.ipynb">Colab 개요</a>를 참조하세요. 새 Colab 메모장을 만들려면 위의 파일 메뉴를 사용하거나 다음 링크로 이동하세요. <a href="http://colab.research.google.com#create=true">새 Colab 메모장 만들기</a>
#
# Colab 메모장은 Colab에서 호스팅하는 Jupyter 메모장입니다. Jupyter 프로젝트에 관해 자세히 알아보려면 <a href="https://www.jupyter.org">jupyter.org</a>를 참조하세요.

# %% [markdown]
# ## 데이터 과학
#
' 썬디드롭스400', ' 키즈딸기200'], '이은찬': ['아이조아징크', ' 아이조아유산균추어블', ' 멀티비타츄어블'], '이준환': ['키즈딸기200', ' 썬디드롭스400', ' 멀티비타츄어블'], '이진리': ['드시모네4500', ' 썬디드롭스400'], '이한비': ['드시모네캡슐', ' 썬디드롭스400'], '임수민': ['드시모네캡슐'], '임준호': ['아이조아유산균추어블', ' 멀티비타츄어블', ' 썬디드롭스400'], '임효신': ['드시모네캡슐'], '장준용': ['썬디드롭스400', ' 아이조아유산균추어블', ' 멀티비타츄어블'], '전예람': ['드시모네캡슐'], '조상연': ['키즈딸기200', ' 징크츄어블', ' 썬디드롭스400'], '조수현': ['아이조아유산균추어블', ' 징크츄어블', ' 썬디드롭스400'], '조윤찬': ['아이조아징크', ' 멀티비타츄어블'], '조재현': ['썬디드롭스400', ' 징크츄어블', ' 곰돌이츄어블+'], '조해인': ['곰돌이츄어블+', ' 징크츄어블', ' 멀티비타츄어블'], nan: ['0']}

# %%
itemsentence=''
itemexplain = {}
firstexplain=''
intro= '  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다. \n 깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.'
explain={ '유산균':'변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다', '징크':'면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.','썬디':'야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.','멀티':'혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다.'}
lacto = set (['아이조아유산균추어블', '곰돌이츄어블+', '드시모네4500','키즈딸기200' ,'N키즈블루베리','드시모네캡슐'])
vit = set ([' 멀티비타츄어블','멀티비타츄어블'])
vitD = set ([' 썬디드롭스400','썬디드롭스400'])
zinc = set ([' 징크츄어블',' 아이조아징크','징크츄어블','아이조아징크'])
number = 0
bridge =""
def bridgeexp(number):
  if number == 1:
    return "그리고 "
  elif number ==2:
    return " 또한 "
  elif number ==3:
    return " 끝으로 "

  
for name, products in list.items():
  firstexplain= str(name[1:3]) + intro +'모쪼록 이 면역처방# 꾸러미가'+ str(name)+ '님의 건강 관리에 도움이 되길 희망합니다!  \n'
  productsset = set(products)
  if lacto & productsset:
    
    tempt = str(explain['유산균'])
    firstexplain += tempt
  if vit & productsset:
    tempt = str(explain['멀티']) 
    bridge =" 끝으로 " if len(products)>3 else(" 또한 " if len(products)>2 else (" 그리고 " if len(products)>1 else " "))
    firstexplain = firstexplain + bridge + tempt
  if vitD & productsset:
    tempt = str(explain['썬디'])
    bridge =" 끝으로 " if len(products)>3 else(" 또한 " if len(products)>2 else (" 그리고 " if len(products)>1 else " "))
    firstexplain = firstexplain + bridge + tempt
  if zinc & productsset:
    tempt = str(explain['징크'])
    bridge =" 끝으로 " if len(products)>3 else(" 또한 " if len(products)>2 else (" 그리고 " if len(products)>1 else " "))
    firstexplain = firstexplain + bridge + tempt
  
  print(firstexplain)
  print("===========================================================================================")
# Out:
# 재범  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가고재범님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 끝으로 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 끝으로 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 끝으로 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 도현  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김도현님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 끝으로 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 끝으로 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 끝으로 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 민서  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김민서님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다
# ===========================================================================================
# 민제  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김민제님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 끝으로 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 끝으로 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 민준  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김민준님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 끝으로 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 끝으로 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 끝으로 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 선재  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김선재님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 그리고 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다.
# ===========================================================================================
# 재율  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김재율님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 끝으로 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 끝으로 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 재한  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김재한님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 재휘  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김재휘님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 지효  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김지효님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 창성  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김창성님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 태인  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가김태인님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 경철  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가노경철님의 건강 관리에 도움이 되길 희망합니다!
#  또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 성겸  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가문성겸님의 건강 관리에 도움이 되길 희망합니다!
#  또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 세인  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가문세인님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 성주  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가박성주님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 그리고 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 시은  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가박시은님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 유건  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가박유건님의 건강 관리에 도움이 되길 희망합니다!
#  또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 주빈  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가박주빈님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 그리고 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 준성  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가박준성님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 채원  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가박채원님의 건강 관리에 도움이 되길 희망합니다!
#  또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 현우  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가배현우님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 민경  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가성민경님의 건강 관리에 도움이 되길 희망합니다!
#  또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 민우  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가송민우님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 예빈  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가송예빈님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 그리고 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 준영  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가송준영님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 유찬  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가신유찬님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 지애  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가신지애님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 승아  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가오승아님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 소담  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가윤소담님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 그리고 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 바울  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가이바울님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 승민  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가이승민님의 건강 관리에 도움이 되길 희망합니다!
#  또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 은규  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가이은규님의 건강 관리에 도움이 되길 희망합니다!
#  또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 은찬  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가이은찬님의 건강 관리에 도움이 되길 희망합니다!
#  또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 준환  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가이준환님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 진리  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가이진리님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 그리고 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 한비  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가이한비님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 그리고 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 수민  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가임수민님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다
# ===========================================================================================
# 준호  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가임준호님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 효신  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가임효신님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다
# ===========================================================================================
# 준용  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가장준용님의 건강 관리에 도움이 되길 희망합니다!
#  또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다.
# ===========================================================================================
# 예람  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가전예람님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다
# ===========================================================================================
# 상연  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가조상연님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 수현  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가조수현님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 윤찬  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가조윤찬님의 건강 관리에 도움이 되길 희망합니다!
#  그리고 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 그리고 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 재현  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가조재현님의 건강 관리에 도움이 되길 희망합니다!
#  또한 야외 활동이 적어져서 햇빛 쬐는 시간이 부족할 것 같아 면역과 뼈 건강에 도움이 되는 비타민 D도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# 해인  님 안녕하세요. 디어라운드 유상준 약사입니다. 지난번 전화상담과 카톡상담을 참조하여 다음과 같은 품목을 선정하여 정성껏 꾸려 보내드립니다.
#  깨물어 먹을 수는 있는지, 싫어하는 맛은 없는지 여러 상황을 주의깊게 살펴서 선정하였습니다.모쪼록 이 면역처방# 꾸러미가조해인님의 건강 관리에 도움이 되길 희망합니다!
# 변비나 설사, 가스 팽만 등에 도움이 될 수 있는 고함량의 유산균을 넣어드렸습니다 또한 혹시 편식으로 비타민과 미네랄이 부족할 까봐 멀티비타민도 넣어드렸습니다. 또한 면역과 성장에 도움이 되도록 아연 성분의 제품을 선정했습니다.
# ===========================================================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-7cd9abf15e09> in <module>()
#      20
#      21 for name, products in list.items():
# ---> 22   firstexplain= str(name[1:3]) + intro +'모쪼록 이 면역처방# 꾸러미가'+ str(name)+ '님의 건강 관리에 도움이 되길 희망합니다!  \n'
#      23   productsset = set(products)
#      24   if lacto & productsset:
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# Google 드라이브 계정에서 스프레드시트를 비롯한 데이터를 Colab 메모장으로 가져오거나 GitHub 등의 여러 다른 소스에서 데이터를 가져올 수 있습니다. Colab을 데이터 과학에 활용하는 방법과 데이터 가져오기에 관해 자세히 알아보려면 <a href="#working-with-data">데이터 사용하기</a> 아래 링크를 참조하세요.

# %% [markdown]
# ## 머신러닝
#
# Colab을 사용하면 <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">코드 몇 줄</a>만으로 이미지 데이터세트를 가져오고, 이 데이터세트로 이미지 분류기를 학습시키며, 모델을 평가할 수 있습니다. Colab 메모장은 Google 클라우드 서버에서 코드를 실행하므로 사용 중인 컴퓨터의 성능과 관계없이 <a href="#using-accelerated-hardware">GPU 및 TPU</a>를 포함한 Google 하드웨어의 성능을 활용할 수 있습니다. 브라우저만 있으면 사용 가능합니다.

# %% [markdown]
# Colab은 다음과 같은 분야의 머신러닝 커뮤니티에서 널리 쓰이고 있습니다.
# - TensorFlow 시작하기
# - 신경망 개발 및 학습시키기
# - TPU로 실험하기
# - AI 연구 보급하기
# - 튜토리얼 만들기
#
# 머신러닝 적용 사례를 보여 주는 Colab 메모장 샘플을 확인하려면 아래 <a href="#machine-learning-examples">머신러닝 예시</a>를 참조하세요.

# %% [markdown]
# ## 추가 리소스
#
# ### Colab에서 메모장 사용하기
# - [Colaboratory 개요](/notebooks/basic_features_overview.ipynb)
# - [Markdown 가이드](/notebooks/markdown_guide.ipynb)
# - [라이브러리 가져오기 및 종속 항목 설치하기](/notebooks/snippets/importing_libraries.ipynb)
# - [GitHub에서 노트 저장 및 로드하기](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [대화형 양식](/notebooks/forms.ipynb)
# - [대화형 위젯](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [Colab의 TensorFlow 2](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### 데이터로 작업하기
# - [데이터 로드: 드라이브, 스프레드시트, Google Cloud Storage](/notebooks/io.ipynb)
# - [차트: 데이터 시각화하기](/notebooks/charts.ipynb)
# - [BigQuery 시작하기](/notebooks/bigquery.ipynb)
#
# ### 머신러닝 단기집중과정
# 다음은 Google 온라인 머신러닝 과정에서 가져온 일부 메모장입니다. <a href="https://developers.google.com/machine-learning/crash-course/">전체 과정 웹사이트</a>에서 자세한 내용을 확인하세요.
# - [Pandas 소개](/notebooks/mlcc/intro_to_pandas.ipynb)
# - [TensorFlow 개념](/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
# - [TensorFlow 첫걸음](/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)
# - [신경망 소개](/notebooks/mlcc/intro_to_neural_nets.ipynb)
# - [희소 데이터 및 임베딩 소개](/notebooks/mlcc/intro_to_sparse_data_and_embeddings.ipynb)
#
# <a name="using-accelerated-hardware"></a>
# ### 가속 하드웨어 사용하기
# - [GPU를 사용한 TensorFlow](/notebooks/gpu.ipynb)
# - [TPU를 사용한 TensorFlow](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## 머신러닝 예시
#
# Colaboratory 덕분에 가능해진 대화형 머신러닝 분석의 예시를 자세히 살펴보려면 <a href="https://tfhub.dev">TensorFlow Hub</a>의 모델을 사용한 이 튜토리얼을 살펴보세요.
#
# 일부 추천 예시는 다음과 같습니다.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">이미지 분류기 재훈련</a>: 사전에 훈련된 이미지 분류기를 기반으로 꽃을 분류하기 위한 Keras 모델을 구축합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">텍스트 분류</a>: IMDB 영화 리뷰를 <em>긍정적인 리뷰</em> 또는 <em>부정적인 리뷰</em>로 분류합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">스타일 트랜스퍼</a>: 딥 러닝을 사용하여 이미지 간에 스타일을 전이시킵니다.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Multilingual Universal Sentence Encoder Q&amp;A</a>: 머신러닝 모델을 사용하여 SQuAD 데이터 세트의 질문에 답변합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">동영상 보간 유형</a>: 동영상에서 첫 프레임과 마지막 프레임 사이에 발생한 내용을 예측합니다.
